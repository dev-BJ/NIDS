# %%
from scapy.all import sniff

# %%
def get_packet(packet):
    packet.show()

# %%
sniff(iface='Wi-Fi', prn=get_packet, count=5)
# Out:
# ###[ Ethernet ]###
#   dst       = ff:ff:ff:ff:ff:ff
#   src       = e4:38:83:73:d9:d5
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 357
#      id        = 43738
#      flags     = DF
#      frag      = 0
#      ttl       = 64
#      proto     = udp
#      chksum    = 0xc9b9
#      src       = 192.168.4.76
#      dst       = 255.255.255.255
#      \options   \
# ###[ UDP ]###
#         sport     = 47938
#         dport     = 10001
#         len       = 337
#         chksum    = 0x6fad
# ###[ Raw ]###
# ...
